# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from sklearn import cross_validation
from sklearn.model_selection import train_test_split


from sklearn import linear_model
from sklearn.linear_model import Ridge

from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.svm import SVR

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import mean_squared_error

from sklearn.neural_network import MLPClassifier


from sklearn import preprocessing
from sklearn import utils
# 
#dataset = pd.read_csv("just-wheat-featured-scaled-T.csv")
#dataset = pd.read_csv("just-wheat.csv")
#dataset = pd.read_csv("just-wheat-T.csv")
#dataset = pd.read_csv("jute.csv")
dataset = pd.read_csv("rejute.csv")
#dataset = pd.read_csv("just wheat featured scaled.csv")
#dataset = pd.read_csv("new temp.csv")
#categorical = pd.read_csv("categorical.csv")

# %%
#dataset
#categorical

# %%
choice = 1

if choice == 1:
    #X = dataset[['Area of Land in acres','Rainfall in MM','Year']]
    #X = dataset[['Area of Land in acres','Rainfall in MM', 'Temparature degree cellcius']]
    X = dataset[['Area Name','Area of Land in acres','Rainfall in MM']]
    y = dataset[['Amount of Production in Tons']]
    
elif choice == 2:
    
    X = dataset[['Area of Land in acres','Amount of Production in Tons','Year']]
    y = dataset[['Rainfall in MM']]
    # y=lab_enc.fit_transform(y)
    
    
elif choice == 3:
    X = dataset[['Year']]
    y = dataset[['Area of Land in acres','Amount of Production in Tons','Rainfall in MM']]
    
elif choice == 4:
    X = dataset[['Area Name']]
    y = dataset[['Area of Land in acres']]
    
elif choice == 5:
    X = dataset[['Area Name']]
    y = dataset[['Amount of Production in Tons']]
    
elif choice == 6:
    X = dataset[['Area Name']]
    y = dataset[['Rainfall in MM']]

elif choice == 7:
    X = dataset[['Area Name']]
    y = dataset[['Temparature Data']]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=20)
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3,random_state=1)

# %%
selectModel = 10

if selectModel == 1:
    clf = linear_model.LinearRegression()

elif selectModel == 2:
    #y_train = y_train.values.ravel()
    clf = RandomForestClassifier(max_depth=5, n_estimators=20, max_features=3)

elif selectModel == 3:
    clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(60, 60, 60, 60, 60), random_state=1)

elif selectModel == 4:
    y_train = y_train.values.ravel()
    clf = SVC(gamma=0.001, C=100.)

elif selectModel == 5:
    clf = Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,normalize=False, random_state=None, solver='auto', tol=0.001)

elif selectModel == 6:
    clf = linear_model.Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
   normalize=False, positive=False, precompute=False, random_state=None,
   selection='cyclic', tol=0.0001, warm_start=False)

elif selectModel == 7:
    clf = AdaBoostClassifier()

elif selectModel == 8:  
    #dataset = columns ['Crop Name' ,'Area Name','Area of Land in acres','Amount of Production in Tons','Rainfall in MM','Year']
    clf = KNeighborsClassifier(n_neighbors = 1.2)

elif selectModel == 9:
    clf = LinearSVC(random_state=0)
elif selectModel == 10:
    clf = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='auto',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)


#y_train = y_train.values.ravel()
model = clf.fit(X_train,y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
accuracy= clf.score(X_test, y_test)
print("The accuracy of the network is:", accuracy)
print("Prediction for the Test set is:")
print( clf.predict(X_test) )
print("Lets Compare it to the original target test set:")
print(y_test)
# Out:
# The accuracy of the network is: -0.2169439811094338
# Prediction for the Test set is:
# [ 5.54844696  9.48987297  6.0403236   8.3884773   4.6100332   8.64192743
#   6.49718266  4.51727497  8.73722374  8.73721176  8.73739596  9.65508035
#   8.30140533  5.93964967  7.46768698  8.32415934  7.64825809  8.73722373
#   4.64070085  8.74068318  8.61593286  8.74222034  8.65813496  8.73966286
#   8.02069242  8.92609933  8.74551106  7.87593816  5.71218802  8.73722379
#   7.84998869  8.78948956  6.23413586  7.27348967  9.25722545  8.73731892
#   3.42976542  9.00082091  8.73722689  8.80670718  7.89978294  4.89861938
#   8.14157068  7.41248267  9.09380227  8.73901015  4.34092558  8.73722373
#   6.94375587  7.5958169   8.73722373  8.55698565  8.77635712  8.74027565
#   8.73722373  7.46674946  8.64893861  8.73722382  7.209551    8.7375592
#   9.28747765  9.00083028  8.73722373  8.74070292  8.87251727  8.73722435
#   9.25064085  9.12680091  1.9187398   8.73722373  4.10657111  8.73722824
#   8.57818388  8.29640031  8.32032071  8.73215525  4.97568094  8.93452822
#   2.6810925   8.73741422  8.72857007  8.73722689  9.54305761  8.74074653
#  10.03073699  8.73722373  8.74213835  8.7372175   9.2302791   5.70540675
#   9.92234608  7.76508514  8.73728258  9.1648809   8.15602203  8.75034746
#   8.78641771  8.75065119]
# Lets Compare it to the original target test set:
#       Amount of Production in Tons
# 1566                             0
# 1569                            21
# 799                              0
# 1040                             0
# 307                              0
# 975                              1
# 996                              1
# 544                              0
# 460                             34
# 1155                             0
# 391                             39
# 1435                            21
# 482                              8
# 798                              0
# 128                             12
# 739                              6
# 1403                             5
# 1380                            44
# 1390                             1
# 487                            171
# 1417                             0
# 163                              0
# 1459                           240
# 993                             11
# 1044                             0
# 1194                             4
# 1502                           207
# 53                               0
# 1338                            11
# 9                                0
# ...                            ...
# 675                              0
# 269                            108
# 514                              0
# 1438                            50
# 321                              7
# 459                              5
# 427                              2
# 1050                             0
# 730                              0
# 1640                            23
# 1391                             0
# 214                             67
# 1330                             0
# 36                              16
# 1599                            49
# 647                             83
# 495                             24
# 888                            144
# 803                            194
# 1073                             0
# 345                             49
# 412                              0
# 693                             75
# 41                               3
# 407                             87
# 54                              23
# 858                              0
# 287                            130
# 424                             17
# 789                             23
#
# [338 rows x 1 columns]

# %%
# le = preprocessing.LabelEncoder()
# c = categorical.values.ravel()
# le.fit(c)
# m=le.transform(c)

# %%
# l=le.inverse_transform(m)
# np.column_stack((m,l))

# %%
seed = 7
kfold = model_selection.KFold(n_splits=10, random_state=seed)
scoring = 'neg_mean_squared_error'
results = model_selection.cross_val_score(clf, X, y, cv=kfold, scoring=scoring)
print("MSE: %.3f (%.3f)") % (results.mean(), results.std())
mean_squared_error(clf.predict(X_test), y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MSE: %.3f (%.3f)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-166-d6b4c4c46e43> in <module>()
#       3 scoring = 'neg_mean_squared_error'
#       4 results = model_selection.cross_val_score(clf, X, y, cv=kfold, scoring=scoring)
# ----> 5 print("MSE: %.3f (%.3f)") % (results.mean(), results.std())
#       6 mean_squared_error(clf.predict(X_test), y_test)
#
# TypeError: unsupported operand type(s) for %: 'NoneType' and 'tuple'

# %%
# plt.plot(X,y,'k+') 
# plt.plot(X_test,y_test,"+") 
# plt.show()
