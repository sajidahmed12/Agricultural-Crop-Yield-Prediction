# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import cross_validation
#from sklearn.model_selection import train_test_split


from sklearn import linear_model
from sklearn.linear_model import Ridge

from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.svm import SVR

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

#from sklearn.neural_network import MLPClassifier


from sklearn import preprocessing
from sklearn import utils
from math import sqrt
# 
#dataset = pd.read_csv("just-wheat-featured-scaled-T.csv")
#dataset = pd.read_csv("just-wheat.csv")
#dataset = pd.read_csv("just-wheat-T.csv")
#dataset = pd.read_csv("jute.csv")
dataset = pd.read_csv("data/rejute.csv")
#dataset = pd.read_csv("just wheat featured scaled.csv")
#dataset = pd.read_csv("new temp.csv")
#categorical = pd.read_csv("categorical.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4c46a36132e1> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn import cross_validation
#       5 #from sklearn.model_selection import train_test_split
#       6
#
# ImportError: cannot import name 'cross_validation'

# %%
#dataset
#categorical

# %%
choice = 1

if choice == 1:
    #X = dataset[['Area of Land in acres','Rainfall in MM','Year']]
    #X = dataset[['Area of Land in acres','Rainfall in MM', 'Temparature degree cellcius']]
    X = dataset[['Area Name','Area of Land in acres','Rainfall in MM']]
    y = dataset[['Amount of Production in Tons']]
    
elif choice == 2:
    
    X = dataset[['Area of Land in acres','Amount of Production in Tons','Year']]
    y = dataset[['Rainfall in MM']]
    # y=lab_enc.fit_transform(y)
    
    
elif choice == 3:
    X = dataset[['Year']]
    y = dataset[['Area of Land in acres','Amount of Production in Tons','Rainfall in MM']]
    
elif choice == 4:
    X = dataset[['Area Name']]
    y = dataset[['Area of Land in acres']]
    
elif choice == 5:
    X = dataset[['Area Name']]
    y = dataset[['Amount of Production in Tons']]
    
elif choice == 6:
    X = dataset[['Area Name']]
    y = dataset[['Rainfall in MM']]

elif choice == 7:
    X = dataset[['Area Name']]
    y = dataset[['Temparature Data']]

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y, test_size=0.2,random_state=20)
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3,random_state=1)

# %%
selectModel = 1

if selectModel == 1:
    clf = linear_model.LinearRegression()

elif selectModel == 2:
    #y_train = y_train.values.ravel()
    clf = RandomForestClassifier(max_depth=5, n_estimators=20, max_features=3)

elif selectModel == 3:
    clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(60, 60, 60, 60, 60), random_state=1)

elif selectModel == 4:
    y_train = y_train.values.ravel()
    clf = SVC(gamma=0.001, C=100.)

elif selectModel == 5:
    clf = Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,normalize=False, random_state=None, solver='auto', tol=0.001)

elif selectModel == 6:
    clf = linear_model.Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
   normalize=False, positive=False, precompute=False, random_state=None,
   selection='cyclic', tol=0.0001, warm_start=False)

elif selectModel == 7:
    clf = AdaBoostClassifier()

elif selectModel == 8:  
    #dataset = columns ['Crop Name' ,'Area Name','Area of Land in acres','Amount of Production in Tons','Rainfall in MM','Year']
    clf = KNeighborsClassifier(n_neighbors = 1.2)

elif selectModel == 9:
    clf = LinearSVC(random_state=0)
elif selectModel == 10:
    clf = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='auto',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False
#  -2.05733971e+00 -1.90520228e+00  5.65585597e+00  1.75447474e+00
#   3.37689389e+01  1.41736663e+01 -1.42780737e+00  1.26658351e+02
#   2.01494060e-01  2.34342013e+00  5.53094996e+01  2.47939897e+00
#   1.26432893e+02  9.18626900e+01  8.16651910e+01 -1.02868462e+00
#  -3.25573440e+00  5.15241011e+01  2.02469760e-01  1.82875790e+02
#   9.54236055e+01  6.90616210e+01  3.78729126e+00  5.14164896e+01
#   1.26821758e+02  8.55846170e+01  1.13171437e+02  3.88305218e+01
#  -1.64793422e+00  1.20607267e+02 -2.27305967e+00  3.37528057e+01
#   7.57474263e+00  5.24985630e+00  1.69287980e+00  1.33909484e+01
#  -2.55236216e+00  1.52659039e+01 -6.10465363e-01  9.93425635e+01
#  -9.08864368e-01  3.48108001e+01  3.89665006e+01  8.71171083e+01
#   2.63991469e+01  1.27413061e+02  1.78176595e+02 -2.35720767e+00
#   4.73772289e+01 -1.22971496e+00  8.26468901e+01  3.54524600e+00
#   9.74266148e+01  5.20734244e+01  1.36269680e+00  1.10321707e+02
#   2.04771795e+01  2.22727640e+01]
# Lets Compare it to the original target test set:
#       Amount of Production in Tons
# 1566                             0
# 1569                            21
# 799                              0
# 1040                             0
# 307                              0
# 975                              1
# 996                              1
# 544                              0
# 460                             34
# 1155                             0
# 391                             39
# 1435                            21
# 482                              8
# 798                              0
# 128                             12
# 739                              6
# 1403                             5
# 1380                            44
# 1390                             1
# 487                            171
# 1417                             0
# 163                              0
# 1459                           240
# 993                             11
# 1044                             0
# 1194                             4
# 1502                           207
# 53                               0
# 1338                            11
# 9                                0
# ...                            ...
# 675                              0
# 269                            108
# 514                              0
# 1438                            50
# 321                              7
# 459                              5
# 427                              2
# 1050                             0
# 730                              0
# 1640                            23
# 1391                             0
# 214                             67
# 1330                             0
# 36                              16
# 1599                            49
# 647                             83
# 495                             24
# 888                            144
# 803                            194
# 1073                             0
# 345                             49
# 412                              0
# 693                             75
# 41                               3
# 407                             87
# 54                              23
# 858                              0
# 287                            130
# 424                             17
# 789                             23
#
# [338 rows x 1 columns]

# %%
# le = preprocessing.LabelEncoder()
# c = categorical.values.ravel()
# le.fit(c)
# m=le.transform(c)

# %%
# l=le.inverse_transform(m)
# np.column_stack((m,l))

# %%
# seed = 7
# kfold = cross_validation.KFold(n=8, n_folds=4, shuffle=False,random_state=seed)
# scoring = 'neg_mean_squared_error'
# results = cross_validation.cross_val_score(clf, X, y, cv=kfold, scoring=scoring)
# print("MSE: %.3f (%.3f)") % (results.mean(), results.std())
m1 = sqrt(mean_squared_error(clf.predict(X_test), y_test))
m2 = mean_absolute_error(clf.predict(X_test), y_test)

#m1
m2
# Out:
# 7.89566247502377

# %%
# plt.plot(X,y,'k+') 
# plt.plot(X_test,y_test,"+") 
# plt.show()
