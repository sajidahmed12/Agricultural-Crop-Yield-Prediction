# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit
from sklearn.model_selection import train_test_split
#from sklearn.model_selection import train_test_split


from sklearn import linear_model
from sklearn.linear_model import Ridge

from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.svm import SVR

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

#from sklearn.neural_network import MLPClassifier


from sklearn import preprocessing
from sklearn import utils
from math import sqrt
# 
#dataset = pd.read_csv("just-wheat-featured-scaled-T.csv")
#dataset = pd.read_csv("just-wheat.csv")
#dataset = pd.read_csv("just-wheat-T.csv")
#dataset = pd.read_csv("jute.csv")
dataset = pd.read_csv("data/rejute.csv")
#dataset = pd.read_csv("just wheat featured scaled.csv")
#dataset = pd.read_csv("new temp.csv")
#categorical = pd.read_csv("categorical.csv")

# %%
#dataset
#categorical

# %%
choice = 1

if choice == 1:
    #X = dataset[['Area of Land in acres','Rainfall in MM','Year']]
    #X = dataset[['Area of Land in acres','Rainfall in MM', 'Temparature degree cellcius']]
    X = dataset[['Area Name','Area of Land in acres','Rainfall in MM']]
    y = dataset[['Amount of Production in Tons']]
    
elif choice == 2:
    
    X = dataset[['Area of Land in acres','Amount of Production in Tons','Year']]
    y = dataset[['Rainfall in MM']]
    # y=lab_enc.fit_transform(y)
    
    
elif choice == 3:
    X = dataset[['Year']]
    y = dataset[['Area of Land in acres','Amount of Production in Tons','Rainfall in MM']]
    
elif choice == 4:
    X = dataset[['Area Name']]
    y = dataset[['Area of Land in acres']]
    
elif choice == 5:
    X = dataset[['Area Name']]
    y = dataset[['Amount of Production in Tons']]
    
elif choice == 6:
    X = dataset[['Area Name']]
    y = dataset[['Rainfall in MM']]

elif choice == 7:
    X = dataset[['Area Name']]
    y = dataset[['Temparature Data']]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=20)
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3,random_state=1)

# %%
selectModel = 1

if selectModel == 1:
    clf = linear_model.LinearRegression()

elif selectModel == 2:
    #y_train = y_train.values.ravel()
    clf = RandomForestClassifier(max_depth=5, n_estimators=20, max_features=3)

elif selectModel == 3:
    clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(60, 60, 60, 60, 60), random_state=1)

elif selectModel == 4:
    y_train = y_train.values.ravel()
    clf = SVC(gamma=0.001, C=100.)

elif selectModel == 5:
    clf = Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,normalize=False, random_state=None, solver='auto', tol=0.001)

elif selectModel == 6:
    clf = linear_model.Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
   normalize=False, positive=False, precompute=False, random_state=None,
   selection='cyclic', tol=0.0001, warm_start=False)

elif selectModel == 7:
    clf = AdaBoostClassifier()

elif selectModel == 8:  
    #dataset = columns ['Crop Name' ,'Area Name','Area of Land in acres','Amount of Production in Tons','Rainfall in MM','Year']
    clf = KNeighborsClassifier(n_neighbors = 1.2)

elif selectModel == 9:
    clf = LinearSVC(random_state=0)
elif selectModel == 10:
    clf = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='auto',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)


#y_train = y_train.values.ravel()

# %%
accuracy= clf.score(X_test, y_test)
print("The accuracy of the network is:", accuracy)
# Out:
# The accuracy of the network is: 0.928691493917639

# %%
# %matplotlib notebook
plt.plot(X_test,y_test,"+") 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print("Prediction for the Test set is:")
print( clf.predict(X_test) )
# Out:
# Prediction for the Test set is:
# [[ 6.11875246e-01]
#  [ 1.63405393e+01]
#  [ 6.93636033e+00]
#  [ 3.45423562e+00]
#  [-1.16172554e+00]
#  [ 4.23928583e+00]
#  [-2.36264234e-01]
#  [-1.70564091e+00]
#  [ 3.01870009e+01]
#  [-1.80154061e+00]
#  [ 3.89885205e+01]
#  [ 1.88224125e+01]
#  [ 6.70454335e+00]
#  [-1.35834899e+00]
#  [ 1.37613482e+01]
#  [ 6.03737654e+00]
#  [ 3.23024589e+00]
#  [ 5.21178742e+01]
#  [ 1.87805506e-01]
#  [ 1.97858040e+02]
#  [ 6.81333629e-01]
#  [-9.48943504e-01]
#  [ 1.82855189e+02]
#  [ 1.27591091e+01]
#  [-1.28889061e+00]
#  [ 7.84030583e+00]
#  [ 1.47818835e+02]
#  [-1.70270298e+00]
#  [ 5.33694223e+00]
#  [-9.69483607e-01]
#  [ 1.28735214e+01]
#  [ 4.38559246e+01]
#  [ 6.94288429e-02]
#  [ 2.74659189e+01]
#  [ 2.45291785e+01]
#  [ 1.35535199e+00]
#  [ 1.27745725e+02]
#  [-5.95307847e-01]
#  [ 2.30338683e+01]
#  [ 3.62369152e-01]
#  [ 3.21702523e+00]
#  [ 1.32898038e+01]
#  [ 1.23970091e+02]
#  [ 2.85016891e+00]
#  [ 1.07094395e+02]
#  [ 7.79775530e+01]
# ...

# %%
print("Lets Compare it to the original target test set:")
print(y_test)
# Out:
# Lets Compare it to the original target test set:
#       Amount of Production in Tons
# 1566                             0
# 1569                            21
# 799                              0
# 1040                             0
# 307                              0
# 975                              1
# 996                              1
# 544                              0
# 460                             34
# 1155                             0
# 391                             39
# 1435                            21
# 482                              8
# 798                              0
# 128                             12
# 739                              6
# 1403                             5
# 1380                            44
# 1390                             1
# 487                            171
# 1417                             0
# 163                              0
# 1459                           240
# 993                             11
# ...

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
seed = 7
kfold = model_selection.KFold(4, shuffle=False,random_state=seed)
scoring = 'neg_mean_squared_error'

results = cross_val_score(clf, X, y, cv=kfold, scoring=scoring)
# Out:
# array([ -385.51110605, -1183.54404437,  -137.54380367,  -587.77761338])

# %%
m1 = sqrt(mean_squared_error(clf.predict(X_test), y_test))
m2 = mean_absolute_error(clf.predict(X_test), y_test)

#m1
m2
# Out:
# 7.895662475023768

# %%
# %matplotlib notebook
plt.title(" Prediction of Rice Production in Tons")
plt.xlabel("DATA X: Area of Land in acres' , ' Rainfall in MM', 'Year")
plt.ylabel("DATA Y : Predicted Amount of Rice Production in Tons")
plt.plot(X,y,'k+') 
plt.plot(X_test,y_test,"+") 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1003">
